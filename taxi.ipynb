# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2 = sns.load_dataset("taxis")
df2
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df_total=df2[["passengers", "distance", "fare", "tip", "tolls", "total"]]
df_total
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   passengers  6433 non-null   int64
#  1   distance    6433 non-null   float64
#  2   fare        6433 non-null   float64
#  3   tip         6433 non-null   float64
#  4   tolls       6433 non-null   float64
#  5   total       6433 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 301.7 KB

# %%
df_total.corr()
# Out:
#             passengers  distance      fare       tip     tolls     total
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000

# %%
ax = sns.heatmap(df_total.corr(), vmin=-1, vmax=1, cmap="mako");

# %%
ax = sns.scatterplot(data=df_total, x='fare', y='distance')
coef = df_total['fare'].corr(df_total['distance'])
plt.text(0.07,0.92, f'Coeficiente de correlacion de pearson = {coef:.2f}')
# Out:
# Text(0.07, 0.92, 'Coeficiente de correlacion de pearson = 0.92')

# %%
ax = sns.scatterplot(data=df_total, x='distance', y='fare')
coef = df_total['distance'].corr(df_total['fare'])
plt.text(0.90,0.97, f'Coeficiente de correlacion de pearson = {coef:.2f}')
# Out:
# Text(0.9, 0.97, 'Coeficiente de correlacion de pearson = 0.92')

# %%
pd.plotting.scatter_matrix(df_total, figsize=(12,12));
