# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
df
# Out:
#         var_1     var_2     var_3
# 0    0.496714  0.645917  0.125977
# 1   -0.138264  0.570778  0.204921
# 2    0.647689  0.356097  0.164068
# 3    1.523030  0.986515  0.127733
# 4   -0.234153  0.605775  0.115127
# ..        ...       ...       ...
# 495  0.538910  0.680141  0.113182
# 496 -1.037246  0.618611  0.267363
# 497 -0.190339  0.752717  0.269974
# 498 -0.875618  0.158605  0.251157
# 499 -1.382800  0.880871  0.283742
#
# [500 rows x 3 columns]

# %%
ax = sns.histplot(data=df['var_1'])
ax.set_xlabel('Variable')
ax.set_ylabel('frecuencia');

# %%
ax = sns.histplot(data=df['var_1'], stat='density')
ax.set_xlabel('variable')
ax.set_ylabel('densidades de probabilidad ')
# Out:
# Text(0, 0.5, 'densidades de probabilidad ')

# %%
ax = sns.histplot(data=df['var_1'], stat='density', kde=True, color='green')
ax.set_xlabel('variable')
ax.set_ylabel('densidades de probabilidad ')
# Out:
# Text(0, 0.5, 'densidades de probabilidad ')

# %%
ax = sns.histplot(data=df['var_1'], stat='density', kde=True, bins=100, color='green')
ax.set_xlabel('variable')
ax.set_ylabel('densidades de probabilidad ')
# Out:
# Text(0, 0.5, 'densidades de probabilidad ')

# %%
ax = sns.histplot(data=df['var_1'], stat='density', kde=True, bins=5, color='green')
ax.set_xlabel('variable')
ax.set_ylabel('densidades de probabilidad ')
# Out:
# Text(0, 0.5, 'densidades de probabilidad ')

# %%
ax = sns.displot(df['var_1'], kind='kde')

# %%
ax = sns.violinplot(data=df['var_1'])
ax.set_xlabel('variable')
ax.set_ylabel('valores')
# Out:
# Text(0, 0.5, 'valores')

# %%
no agradecer en las conclusiones 
sacar hipotesis 
de 16-17 años sacar porcentajes
5 preguntas para contestar

cuales son las materias ma dificles para ellos, semestres, si les gusta la carrera,
a que piensan dedicarse, preguntas cerradas,
