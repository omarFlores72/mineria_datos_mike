# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('crimenes.csv')
print(df.columns)
# Out:
# Index(['State', 'Population', 'Murder.Rate', 'Abbreviation'], dtype='object')

# %%
ax = sns.histplot(data=df['Population'], bins=6)
ax.set_xlabel('variale')
ax.set_ylabel('frecuencia (conteo)');
media, std = df['Population'].mean(), df['Population'].std()
ax.axvline(media, color='red', linestyle='--', label=f'media: {media:.1f}')
ax.axvline(media + std, color='green', linestyle='--')
ax.legend();

# %%
ax = sns.boxplot(data=df['Population'],showfliers=False)
ax = sns.stripplot(data=df['Population'], jitter=True, alpha = 0.5)
ax.set_xlabel('variable A') 
ax.set_ylabel('valores')
ax.axhline((Q1 - 1.5 * IQR), color='black', linestyle='--')
ax.axhline((Q3 + 1.5 * IQR), color='black', linestyle='--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3 ax.set_xlabel('variable A')
#       4 ax.set_ylabel('valores')
# ----> 5 ax.axhline((Q1 - 1.5 * IQR), color='black', linestyle='--')
#       6 ax.axhline((Q3 + 1.5 * IQR), color='black', linestyle='--')
#
# NameError: name 'Q1' is not defined
